# %%
#%%timeit -r 4 -n 10000
import cv2
import matplotlib.pyplot as plt
import math
import copy
import numpy as np
 
img = cv2.imread("1.jpg")
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
box = cv2.boxFilter(rgb_img,-1,(5,5),normalize=True)
 
plt.figure(figsize=(13,13))
plt.subplot (1,2,1)
plt.imshow (rgb_img)
plt.subplot(1,2,2)
plt.imshow(box)
 
plt.show()

# %% [markdown]
# ## Оценка времени выполнения

# %%
# %%timeit -r 4 -n 1000
import cv2
import matplotlib.pyplot as plt
import math
import copy
import numpy as np
 
img = cv2.imread("1.jpg")
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
box = cv2.boxFilter(rgb_img,-1,(5,5),normalize=True)
# Out:
# 33.8 ms ± 2.25 ms per loop (mean ± std. dev. of 4 runs, 1000 loops each)

# %% [markdown]
# # Асимптотика алгоритма - $O(Nr)$, где N - количество пикселей изображения, r - радиус Box фильтра.

# %% [markdown]
# ## Оценка зависимости времени выполнения от размера Box фильтра

# %%
import time

runtime = []
ksize = [3, 6, 9, 12, 15, 18, 21]
img = cv2.imread("1.jpg")
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(13,13))
plt.imshow (rgb_img)

fig = plt.figure(figsize=(13, 13))


for idx, size in enumerate(ksize):
    start_time = time.perf_counter()
    box = cv2.boxFilter(rgb_img,-1,(size,size),normalize=True)
    fig.add_subplot(3, 3, idx + 1)
    plt.title(f"{size}x{size}")
    plt.imshow(box)
    runtime.append(time.perf_counter() - start_time)

print(runtime)
# Out:
# [0.04194869999992079, 0.041422700000111945, 0.042088000000148895, 0.15834719999975277, 0.21337779999976192, 0.09779679999974178, 0.042651399999613204]

# %%
fig2 = plt.figure(figsize=(13,13))
plt.plot(ksize, runtime)
plt.xlabel('Размер ядра', fontsize=12)
plt.ylabel('Время выполнения', fontsize=12)
plt.show()

# %% [markdown]
# ## Сравнение с фильтрацией Гаусса

# %%
img = cv2.imread("1.jpg")
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
box = cv2.boxFilter(rgb_img,-1,(15,15),normalize=True)
 
plt.figure(figsize=(13,13))
plt.imshow(box)
 
plt.show()

# %%
img = cv2.imread("1.jpg")
#gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Добавить точечный шум
for i in range(2000):  
    temp_x = np.random.randint(0, rgb_img.shape[0])
    temp_y = np.random.randint(0, rgb_img.shape[1])
    rgb_img[temp_x][temp_y] = 255

plt.figure(figsize=(13,13))
plt.imshow(rgb_img)

gauss = cv2.GaussianBlur(rgb_img,(15,15),0)
plt.figure(figsize=(13,13))
plt.imshow(gauss)


plt.show()

# %% [markdown]
# ## При одинаковом размере ядра свёртки Box фильтрация сильнее размывает фотографию. Гаусс фильтрация позволяет избавиться от шумов на изображении. Размер ядра свёртки для Гауссовской фильтрации должен быть нечётным.
